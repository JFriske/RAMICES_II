# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib as mpl
import pandas as pd
#from cycler import cycler
#mpl.rcParams['axes.prop_cycle'] = cycler(color='bgrcmyk')

# %%
kuerzel = 'NucDiskTest'

coldGasMet = pd.read_table('../Output/Test/Enrichment_Absolute_ColdGas.dat',index_col=False , delimiter = ',\s')

coldGasMass = pd.read_table('../Output/Test/Mass.dat',index_col=False, delimiter = ',\s')

coldGasMetLog = pd.read_table('../Output/' + kuerzel + '/Enrichment_Log_ColdGas.dat',index_col=False , delimiter = ',\s')

coldGasMetNuc = pd.read_table('../Output/' + kuerzel + '/Enrichment_Absolute_ColdGas.dat',index_col=False , delimiter = ',\s')

coldGasMassNuc = pd.read_table('../Output/' + kuerzel + '/Mass.dat',index_col=False, delimiter = ',\s')

events = pd.read_table('../Output/' + kuerzel + '/Events.dat',index_col=False, delimiter = ',\s')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py in _infer_columns(self)
#     375                 try:
# --> 376                     line = self._buffered_line()
#     377
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py in _buffered_line(self)
#     583         else:
# --> 584             return self._next_line()
#     585
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py in _next_line(self)
#     680             while True:
# --> 681                 orig_line = self._next_iter_line(row_num=self.pos + 1)
#     682                 self.pos += 1
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py in _next_iter_line(self, row_num)
#     741             assert self.data is not None
# --> 742             return next(self.data)
#     743         except csv.Error as e:
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# EmptyDataError                            Traceback (most recent call last)
# /tmp/ipykernel_13195/1392997745.py in <module>
#       5 coldGasMass = pd.read_table('../Output/Test/Mass.dat',index_col=False, delimiter = ',\s')
#       6
# ----> 7 coldGasMetLog = pd.read_table('../Output/' + kuerzel + '/Enrichment_Log_ColdGas.dat',index_col=False , delimiter = ',\s')
#       8
#       9 coldGasMetNuc = pd.read_table('../Output/' + kuerzel + '/Enrichment_Absolute_ColdGas.dat',index_col=False , delimiter = ',\s')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, encoding_errors, delim_whitespace, low_memory, memory_map, float_precision)
#     681     kwds.update(kwds_defaults)
#     682
# --> 683     return _read(filepath_or_buffer, kwds)
#     684
#     685
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py in __init__(self, f, **kwds)
#     111                 self.num_original_columns,
#     112                 self.unnamed_cols,
# --> 113             ) = self._infer_columns()
#     114         except (TypeError, ValueError):
#     115             self.close()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py in _infer_columns(self)
#     396
#     397                     if not self.names:
# --> 398                         raise EmptyDataError("No columns to parse from file") from err
#     399
#     400                     line = self.names[:]
#
# EmptyDataError: No columns to parse from file

# %%
ringNumber = 50
ringwidth= 0.015/5

# %%
#coldGasMassNuc0 = coldGasMassNuc[coldGasMassNuc['Radius'] == 0.00375]
gasRings = []
for i in range(ringNumber):
    a = coldGasMassNuc[coldGasMassNuc['Radius'] == (i+ 0.5)*ringwidth ]

    gasRings.append(a)
    
figure(figsize=(8, 6), dpi=150)
for i in range(ringNumber):
    ring = gasRings[i]
    x = ring['Time']
    y = ring['ColdGasMass']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 

#plt.legend()
plt.show()

figure(figsize=(8, 6), dpi=150)

for i in range(ringNumber):
    ring = gasRings[i]
    x = ring['Time']
    y = ring['HotGasMass']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 

#plt.legend()
plt.show()

# %%
#coldGasMassNuc0 = coldGasMassNuc[coldGasMassNuc['Radius'] == 0.00375]
gasRings = []
for i in range(ringNumber):
    a = events[events['Radius'] == (i+ 0.5)*ringwidth ]
    gasRings.append(a)
    
    

figure(figsize=(8, 6), dpi=150)

for i in range(ringNumber):
    event = gasRings[i]
    x = event['Time']
    y = event['FormationEfficiency']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 
    plt.yscale('log')
#plt.legend()
plt.show()

figure(figsize=(8, 6), dpi=150)

for i in range(ringNumber):
    event = gasRings[i]
    x = event['Time']
    y = event['AGBRate']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 
    plt.yscale('log')
    plt.vlines(3.5, -10,1000000)
    
#plt.legend()
plt.show()

# %%
#print(coldGasMetLog['Total_Mg'])

# %%
fig =figure(figsize=(12, 8), dpi=150)

#coldGasMassNuc0 = coldGasMassNuc[coldGasMassNuc['Radius'] == 0.00375]
gasRings = []
for i in range(ringNumber):
    a = coldGasMetLog[coldGasMetLog['RingIndex'] == i]
    gasRings.append(a)

    
fig.add_subplot(221)    
for i in range(ringNumber):
    ring = gasRings[i]
    plt.ylim(-0.5,1)
    x = ring['Time']
    y = ring['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 
    
plt.vlines(3.5, -10,10)
plt.vlines(4.0, -10,10)
plt.ylim(0.2,0.85)
plt.xlabel('time')
plt.ylabel('[Fe/H]')
#plt.legend()
#plt.show()
#figure(figsize=(8, 6), dpi=150)

fig.add_subplot(222)

for i in range(ringNumber):
    ring = gasRings[i]
    x = ring['Time']
    y = ring['Total_Mg'] -ring['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 
plt.vlines(3.5, -10,10)
plt.vlines(4.0, -10,10)
plt.ylim(-0.1,0.3)
plt.ylabel('[Mg/Fe]')
plt.xlabel('time')
#plt.legend()
#plt.show()
#figure(figsize=(8, 6), dpi=150)

fig.add_subplot(223)

for i in range(ringNumber):
    ring = gasRings[i]
    x = ring['Total_Fe']
    y = ring['Total_Mg'] -ring['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 
plt.vlines(3.5, -10,10)
plt.vlines(4.0, -10,10)
plt.xlim(0.05,0.85)         
plt.ylim(-0.05,0.25)
#plt.legend()
plt.xlabel('[Fe/H]')
plt.ylabel('[Mg/Fe]')


fig.add_subplot(224)

for i in range(ringNumber):
    ring = gasRings[i]
    x = ring['Total_Fe']
    y = ring['Total_Co'] -ring['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    plt.plot(x,y, color=colors[i], label = i) 
plt.vlines(3.5, -10,10)
plt.vlines(4.0, -10,10)
plt.xlim(0.05,0.85)         
plt.ylim(-0.05,0.25)
#plt.legend()
plt.xlabel('[Co/H]')
plt.ylabel('[Mg/Fe]')

plt.savefig('metplanes'+kuerzel+'.pdf') 
plt.show()


ring = gasRings[1]
x =ring['Total_Fe']
y = ring['Total_Mg'] - ring['Total_Fe']
c = ring['Time']
plt.scatter(x,y,c=c)
plt.colorbar()
plt.xlim(0.25,0.6)         
plt.ylim(-0.05,0.19)


ring = gasRings[10]
x =ring['Total_Fe']
y = ring['Total_Mg'] - ring['Total_Fe']
c = ring['Time']
plt.scatter(x,y,c=c)
plt.colorbar()
plt.xlim(0.25,0.85)         
plt.ylim(-0.05,0.19)


ring = gasRings[40]
x =ring['Total_Fe']
y = ring['Total_Mg'] - ring['Total_Fe']
c = ring['Time']
plt.scatter(x,y,c=c)
plt.colorbar()
plt.xlim(0.25,0.85)         
plt.ylim(-0.05,0.19)

# %%
a = coldGasMetLog[coldGasMetLog['Time'] == 11.97]

fig = plt.figure(figsize=(12, 8), dpi=150)
y = np.zeros(ringNumber) 
x = np.arange(ringNumber)

for i in range(ringNumber):
    b = a[a['RingIndex'] == i]
    y[i] = b['Total_Mg'] -b['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))

fig.add_subplot(221)        
    
plt.scatter(x*ringwidth,y, color=colors[x]) 

plt.ylabel('Mg/Fe')
plt.xlabel('Radius')
plt.ylim(-0.05,0.05)
#plt.legend()


y = np.zeros(ringNumber) 

for i in range(ringNumber):
    b = a[a['RingIndex'] == i]
    y[i] = b['Total_Eu'] -b['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))
    
fig.add_subplot(222)    
    
plt.scatter(x*ringwidth,y, color=colors[x]) 

plt.ylabel('Eu/Fe')
plt.xlabel('Radius')
plt.ylim(-0.1,0.2)
#plt.legend()


fig.add_subplot(223)   

y = np.zeros(ringNumber) 

for i in range(ringNumber):
    b = a[a['RingIndex'] == i]
    y[i] =b['Total_Fe']
    colors = plt.cm.turbo(np.linspace(0,1,ringNumber))

plt.ylabel('Fe')
plt.xlabel('Radius')
plt.scatter(x*ringwidth,y, color=colors[x]) 

plt.ylim(0.7,0.78)
#plt.legend()
plt.savefig('NucDiskGradient'+kuerzel+'.pdf') 
#plt.show()
